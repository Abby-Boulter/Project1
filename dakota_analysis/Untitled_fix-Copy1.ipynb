# %%
# Dependencies
import csv
import os
import pandas as pd
import requests
import matplotlib.pyplot as plt
api_key = "51ed96e7"
url = "http://www.omdbapi.com/?apikey=" + api_key + "&t="

# %%
#lists
responses = []
meta_score = []
imdb_score = []
boxoffice = []
genre = []
not_found= []

# %%
#read csv and create list of movie titles
movie_1_path = os.path.join('movie_title_1.csv')

titles_1 = []
with open(movie_1_path) as file_1:
    reader_1 = csv.reader(file_1, delimiter=",")
    print(reader_1)

    try:
        for title in reader_1:
        titles_1.append(title[1])
    except:
        pass

# %%
# Make a request to the OMDb API for each movie in the list.
for movie in titles_1:
    movie_data = requests.get(url + movie).json()

    try:
        mscore = movie_data["Metascore"]
        iscore = movie_data["imdbRating"]
        boffice = int((movie_data["BoxOffice"].replace('$', '')).replace(',', ''))
        mtype = movie_data["Genre"]
        print(f"{movie} is an {mtype} movie with a IMDB sorec of {iscore}, a Meta score of {mscore}, and made {boffice} at the box office")
        print("---------------------")
        meta_score.append(mscore)
        imdb_score.append(iscore)
        boxoffice.append(boffice)
        genre.append(mtype)
    except:
        print(f"{movie} not found")
        print("---------------------")
        not_found.append(movie)
        pass

# %%
movie_2_path = os.path.join('movie_title_2.csv')

titles_2 =[]
with open(movie_2_path) as file_2:
    reader_2 = csv.reader(file_2, delimiter=",")
    print(reader_2)

    try:
        for title in reader_2:
            titles_2.append(title[1])
    except:
        pass

# %%
# Make a request to the OMDb API for each movie in the list.
for movie in titles_2:
    movie_data = requests.get(url + movie).json()

    try:
        mscore = movie_data["Metascore"]
        iscore = movie_data["imdbRating"]
        boffice = int((movie_data["BoxOffice"].replace('$', '')).replace(',', ''))
        mtype = movie_data["Genre"]
        print(f"{movie} is an {mtype} movie with a IMDB sorec of {iscore}, a Meta score of {mscore}, and made {boffice} at the box office")
        print("---------------------")
        meta_score.append(mscore)
        imdb_score.append(iscore)
        boxoffice.append(boffice)
        genre.append(mtype)
    except:
        print(f"{movie} not found")
        print("---------------------")
        not_found.append(movie)
        pass

# %%
#read csv and create list of movie titles
movie_3_path = os.path.join('movie_title_3.csv')

titles_3 = []
with open(movie_3_path) as file_3:
    reader_3 = csv.reader(file_3, delimiter=",")
    print(reader_3)

    try:
        for title in reader_3:
            titles_3.append(title[1])
    except:
        pass
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24064\2622939049.py in <module>
#       3
#       4 titles_3 = []
# ----> 5 with open(movie_3_path) as file_3:
#       6     reader_3 = csv.reader(file_3, delimiter=",")
#       7     print(reader_3)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'movie_title_3.csv'

# %%
# Make a request to the OMDb API for each movie in the list.
for movie in titles_3:
    movie_data = requests.get(url + movie).json()

    try:
        mscore = movie_data["Metascore"]
        iscore = movie_data["imdbRating"]
        boffice = int((movie_data["BoxOffice"].replace('$', '')).replace(',', ''))
        mtype = movie_data["Genre"]
        print(f"{movie} is an {mtype} movie with a IMDB sorec of {iscore}, a Meta score of {mscore}, and made {boffice} at the box office")
        print("---------------------")
        meta_score.append(mscore)
        imdb_score.append(iscore)
        boxoffice.append(boffice)
        genre.append(mtype)
    except:
        print(f"{movie} not found")
        print("---------------------")
        not_found.append(movie)
        pass

# %%
#read csv and create list of movie titles
movie_4_path = os.path.join('movie_title_4.csv')

titles_4 = []
with open(movie_4_path) as file_4:
    reader_4 = csv.reader(file_4, delimiter=",")
    print(reader_4)

    try:
        for title in reader_4:
            titles_4.append(title[1])
    except:
        pass
# Out:
# <_csv.reader object at 0x000002A1BF4C6A00>

# %%
# Make a request to the OMDb API for each movie in the list.
for movie in titles_4:
    movie_data = requests.get(url + movie).json()

    try:
        mscore = movie_data["Metascore"]
        iscore = movie_data["imdbRating"]
        boffice = int((movie_data["BoxOffice"].replace('$', '')).replace(',', ''))
        mtype = movie_data["Genre"]
        print(f"{movie} is an {mtype} movie with a IMDB sorec of {iscore}, a Meta score of {mscore}, and made {boffice} at the box office")
        print("---------------------")
        meta_score.append(mscore)
        imdb_score.append(iscore)
        boxoffice.append(boffice)
        genre.append(mtype)
    except:
        print(f"{movie} not found")
        print("---------------------")
        not_found.append(movie)
        pass
# Out:
# 0 not found
# ---------------------
# John Wick: Chapter 3 - Parabellum is an Action, Crime, Thriller movie with a IMDB sorec of 7.4, a Meta score of 73, and made 171015687 at the box office
# ---------------------
# John Wick is an Action, Crime, Thriller movie with a IMDB sorec of 7.4, a Meta score of 68, and made 43037835 at the box office
# ---------------------
# Me Before You is an Drama, Romance movie with a IMDB sorec of 7.4, a Meta score of 51, and made 56245075 at the box office
# ---------------------
# Avengers: Endgame is an Action, Adventure, Drama movie with a IMDB sorec of 8.4, a Meta score of 78, and made 858373000 at the box office
# ---------------------
# Brothers is an Drama, Thriller, War movie with a IMDB sorec of 7.1, a Meta score of 58, and made 28544157 at the box office
# ---------------------
# Frozen II is an Animation, Adventure, Comedy movie with a IMDB sorec of 6.8, a Meta score of 64, and made 477373578 at the box office
# ---------------------
# Fast & Furious Presents: Hobbs & Shaw is an Action, Adventure, Crime movie with a IMDB sorec of 7.0, a Meta score of 61, and made 238679850 at the box office
# ---------------------
# The Green Mile is an Crime, Drama, Fantasy movie with a IMDB sorec of 8.6, a Meta score of 61, and made 136801374 at the box office
# ---------------------
# The Lion King is an Animation, Adventure, Drama movie with a IMDB sorec of 8.5, a Meta score of 88, and made 422783777 at the box office
# ---------------------
# Grown Ups 2 is an Comedy movie with a IMDB sorec of 5.3, a Meta score of 19, and made 133668525 at the box office
# ---------------------
# It Chapter Two is an Drama, Fantasy, Horror movie with a IMDB sorec of 6.5, a Meta score of 58, and made 211622525 at the box office
# ---------------------
# How to Train Your Dragon: The Hidden World is an Animation, Action, Adventure movie with a IMDB sorec of 7.4, a Meta score of 71, and made 160945505 at the box office
# ---------------------
# Toy Story 4 is an Animation, Adventure, Comedy movie with a IMDB sorec of 7.7, a Meta score of 84, and made 434038008 at the box office
# ---------------------
# The Matrix is an Action, Sci-Fi movie with a IMDB sorec of 8.7, a Meta score of 73, and made 172076928 at the box office
# ---------------------
# Maleficent: Mistress of Evil is an Adventure, Family, Fantasy movie with a IMDB sorec of 6.6, a Meta score of 43, and made 113929605 at the box office
# ---------------------
# Tinker Bell and the Legend of the NeverBeast not found
# ---------------------
# Joker is an Crime, Drama, Thriller movie with a IMDB sorec of 8.4, a Meta score of 59, and made 335477657 at the box office
# ---------------------
# Jumanji: The Next Level is an Action, Adventure, Comedy movie with a IMDB sorec of 6.7, a Meta score of 58, and made 320314960 at the box office
# ---------------------
# Spider-Man: Far From Home is an Action, Adventure, Comedy movie with a IMDB sorec of 7.4, a Meta score of 69, and made 390532085 at the box office
# ---------------------
# Scarface is an Crime, Drama movie with a IMDB sorec of 8.3, a Meta score of 65, and made 45408703 at the box office
# ---------------------
# The Shawshank Redemption is an Drama movie with a IMDB sorec of 9.3, a Meta score of 82, and made 28767189 at the box office
# ---------------------
# The Pilgrim's Progress not found
# ---------------------
# Blade Runner 2049 is an Action, Drama, Mystery movie with a IMDB sorec of 8.0, a Meta score of 81, and made 92071675 at the box office
# ---------------------
# Annabelle Comes Home is an Horror, Mystery, Thriller movie with a IMDB sorec of 5.9, a Meta score of 53, and made 74152591 at the box office
# ---------------------
# Alita: Battle Angel is an Action, Adventure, Sci-Fi movie with a IMDB sorec of 7.3, a Meta score of 53, and made 85838210 at the box office
# ---------------------
# Watchmen is an Action, Drama, Mystery movie with a IMDB sorec of 7.6, a Meta score of 56, and made 107509799 at the box office
# ---------------------
# Fractured not found
# ---------------------
# Ted is an Comedy movie with a IMDB sorec of 6.9, a Meta score of 62, and made 218815487 at the box office
# ---------------------
# Godzilla: King of the Monsters is an Action, Adventure, Fantasy movie with a IMDB sorec of 6.0, a Meta score of 48, and made 110500138 at the box office
# ---------------------
# Dark Phoenix is an Action, Adventure, Sci-Fi movie with a IMDB sorec of 5.7, a Meta score of 43, and made 65845974 at the box office
# ---------------------
# God's Not Dead: A Light in Darkness is an Drama movie with a IMDB sorec of 4.4, a Meta score of 33, and made 5728940 at the box office
# ---------------------
# Hotel Transylvania 3: Summer Vacation is an Animation, Adventure, Comedy movie with a IMDB sorec of 6.3, a Meta score of 54, and made 167510016 at the box office
# ---------------------
# Solar Impact not found
# ---------------------
# The Addams Family is an Comedy, Fantasy movie with a IMDB sorec of 6.9, a Meta score of 57, and made 113502426 at the box office
# ---------------------
# Knives Out is an Comedy, Crime, Drama movie with a IMDB sorec of 7.9, a Meta score of 82, and made 165363234 at the box office
# ---------------------
# Hellboy is an Action, Adventure, Fantasy movie with a IMDB sorec of 6.8, a Meta score of 72, and made 59623958 at the box office
# ---------------------
# Addams Family Values is an Comedy, Fantasy movie with a IMDB sorec of 6.8, a Meta score of 61, and made 48919043 at the box office
# ---------------------
# Rambo: First Blood Part II is an Action, Adventure, Thriller movie with a IMDB sorec of 6.5, a Meta score of 47, and made 150415432 at the box office
# ---------------------
# Descendants 3 not found
# ---------------------
# PokÃ©mon Detective Pikachu not found
# ---------------------
# Samson is an Action, Drama movie with a IMDB sorec of 4.5, a Meta score of 17, and made 4719928 at the box office
# ---------------------
# Red Shoes and the Seven Dwarfs not found
# ---------------------
# Star Wars: The Rise of Skywalker not found
# ---------------------
# Terminator: Dark Fate is an Action, Adventure, Sci-Fi movie with a IMDB sorec of 6.2, a Meta score of 54, and made 62253077 at the box office
# ---------------------
# Melody Makers not found
# ---------------------
# Overcomer is an Drama, Family, Sport movie with a IMDB sorec of 6.6, a Meta score of 17, and made 34746945 at the box office
# ---------------------
# Rambo: Last Blood is an Action, Crime, Thriller movie with a IMDB sorec of 6.1, a Meta score of 26, and made 44819352 at the box office
# ---------------------
# How to Train Your Dragon: Homecoming not found
# ---------------------
# Chappie is an Action, Crime, Drama movie with a IMDB sorec of 6.8, a Meta score of 41, and made 31569268 at the box office
# ---------------------
# Five Feet Apart is an Drama, Romance movie with a IMDB sorec of 7.2, a Meta score of 53, and made 45729221 at the box office
# ---------------------
# 300 is an Action, Drama movie with a IMDB sorec of 7.6, a Meta score of 52, and made 210629101 at the box office
# ---------------------
# The Expendables 3 is an Action, Adventure, Thriller movie with a IMDB sorec of 6.1, a Meta score of 35, and made 39322544 at the box office
# ---------------------
# The Addams Family is an Comedy, Fantasy movie with a IMDB sorec of 6.9, a Meta score of 57, and made 113502426 at the box office
# ---------------------
# Ready or Not is an Action, Comedy, Horror movie with a IMDB sorec of 6.8, a Meta score of 64, and made 28714231 at the box office
# ---------------------
# Se7en is an Crime, Drama, Mystery movie with a IMDB sorec of 8.6, a Meta score of 65, and made 100125643 at the box office
# ---------------------
# First Blood is an Action, Adventure, Thriller movie with a IMDB sorec of 7.7, a Meta score of 61, and made 47212904 at the box office
# ---------------------
# Steven Universe: The Movie not found
# ---------------------
# The Shining is an Drama, Horror movie with a IMDB sorec of 8.4, a Meta score of 66, and made 45634352 at the box office
# ---------------------
# Angel Has Fallen is an Action, Thriller movie with a IMDB sorec of 6.4, a Meta score of 45, and made 69030436 at the box office
# ---------------------
# A Dog's Journey is an Adventure, Comedy, Drama movie with a IMDB sorec of 7.4, a Meta score of 43, and made 22782371 at the box office
# ---------------------
# Guardians of the Galaxy is an Action, Adventure, Comedy movie with a IMDB sorec of 8.0, a Meta score of 76, and made 333718600 at the box office
# ---------------------
# 1917 is an Action, Drama, War movie with a IMDB sorec of 8.2, a Meta score of 78, and made 159227644 at the box office
# ---------------------
# Blade Runner is an Action, Drama, Sci-Fi movie with a IMDB sorec of 8.1, a Meta score of 84, and made 32914489 at the box office
# ---------------------
# Vivarium not found
# ---------------------
# Ford v Ferrari is an Action, Biography, Drama movie with a IMDB sorec of 8.1, a Meta score of 81, and made 117624357 at the box office
# ---------------------
# Crawl is an Action, Adventure, Horror movie with a IMDB sorec of 6.1, a Meta score of 60, and made 39014193 at the box office
# ---------------------
# The Irishman not found
# ---------------------
# Midsommar is an Drama, Horror, Mystery movie with a IMDB sorec of 7.1, a Meta score of 72, and made 27426361 at the box office
# ---------------------
# Once Upon a Timeâ€¦ in Hollywood not found
# ---------------------
# Just Mercy is an Biography, Crime, Drama movie with a IMDB sorec of 7.6, a Meta score of 68, and made 36001502 at the box office
# ---------------------
# Brian Banks is an Biography, Drama, Sport movie with a IMDB sorec of 7.2, a Meta score of 58, and made 4376819 at the box office
# ---------------------
# The Revenant is an Action, Adventure, Drama movie with a IMDB sorec of 8.0, a Meta score of 76, and made 183637894 at the box office
# ---------------------
# Man on Fire is an Action, Crime, Drama movie with a IMDB sorec of 7.7, a Meta score of 47, and made 77911774 at the box office
# ---------------------
# Children of Men is an Action, Drama, Sci-Fi movie with a IMDB sorec of 7.9, a Meta score of 84, and made 35552383 at the box office
# ---------------------
# The Little Mermaid is an Animation, Adventure, Family movie with a IMDB sorec of 7.6, a Meta score of 88, and made 111543479 at the box office
# ---------------------
# The Angry Birds Movie 2 is an Animation, Action, Adventure movie with a IMDB sorec of 6.4, a Meta score of 60, and made 41667116 at the box office
# ---------------------
# The Secret Life of Pets 2 is an Animation, Adventure, Comedy movie with a IMDB sorec of 6.4, a Meta score of 55, and made 158874395 at the box office
# ---------------------
# Zombieland: Double Tap is an Action, Comedy, Horror movie with a IMDB sorec of 6.7, a Meta score of 55, and made 73123082 at the box office
# ---------------------
# 6 Underground not found
# ---------------------
# Public Enemies is an Action, Biography, Crime movie with a IMDB sorec of 7.0, a Meta score of 70, and made 97104620 at the box office
# ---------------------
# The Gentlemen is an Action, Comedy, Crime movie with a IMDB sorec of 7.8, a Meta score of 51, and made 36471795 at the box office
# ---------------------
# No Strings Attached is an Comedy, Romance movie with a IMDB sorec of 6.2, a Meta score of 50, and made 70662220 at the box office
# ---------------------
# Brightburn is an Drama, Horror, Mystery movie with a IMDB sorec of 6.1, a Meta score of 44, and made 17300439 at the box office
# ---------------------
# Abominable is an Animation, Adventure, Comedy movie with a IMDB sorec of 7.0, a Meta score of 61, and made 61270390 at the box office
# ---------------------
# Solo: A Star Wars Story is an Action, Adventure, Sci-Fi movie with a IMDB sorec of 6.9, a Meta score of 62, and made 213767512 at the box office
# ---------------------
# Halloween is an Horror, Thriller movie with a IMDB sorec of 7.7, a Meta score of 87, and made 47160000 at the box office
# ---------------------
# I See You not found
# ---------------------
# Die Hard 2 is an Action, Thriller movie with a IMDB sorec of 7.1, a Meta score of 67, and made 117540947 at the box office
# ---------------------
# Doctor Sleep is an Drama, Fantasy, Horror movie with a IMDB sorec of 7.3, a Meta score of 59, and made 31581712 at the box office
# ---------------------
# The Adventures of Tintin is an Animation, Action, Adventure movie with a IMDB sorec of 7.3, a Meta score of 68, and made 77591831 at the box office
# ---------------------
# Alvin and the Chipmunks: Chipwrecked is an Animation, Adventure, Comedy movie with a IMDB sorec of 4.3, a Meta score of 24, and made 133110742 at the box office
# ---------------------
# Little Women is an Drama, Romance movie with a IMDB sorec of 7.8, a Meta score of 91, and made 108101214 at the box office
# ---------------------
# The Lighthouse is an Drama, Fantasy, Mystery movie with a IMDB sorec of 7.4, a Meta score of 83, and made 10867104 at the box office
# ---------------------
# Eyes Wide Shut is an Drama, Mystery, Thriller movie with a IMDB sorec of 7.5, a Meta score of 68, and made 55691208 at the box office
# ---------------------
# American Hustle is an Crime, Drama movie with a IMDB sorec of 7.2, a Meta score of 90, and made 150117807 at the box office
# ---------------------
# I Can Only Imagine is an Biography, Drama, Family movie with a IMDB sorec of 7.3, a Meta score of 30, and made 83482352 at the box office
# ---------------------
# Peter Pan is an Animation, Adventure, Family movie with a IMDB sorec of 7.3, a Meta score of 76, and made 87404651 at the box office
# ---------------------
# Jojo Rabbit is an Comedy, Drama, War movie with a IMDB sorec of 7.9, a Meta score of 58, and made 33370906 at the box office
# ---------------------
# Porno not found
# ---------------------
# Apocalypse Now is an Drama, Mystery, War movie with a IMDB sorec of 8.5, a Meta score of 94, and made 96042913 at the box office
# ---------------------
# Scary Stories to Tell in the Dark is an Adventure, Horror, Mystery movie with a IMDB sorec of 6.2, a Meta score of 61, and made 68947075 at the box office
# ---------------------
# Hellboy is an Action, Adventure, Fantasy movie with a IMDB sorec of 6.8, a Meta score of 72, and made 59623958 at the box office
# ---------------------
# Twelve Monkeys not found
# ---------------------
# Dark Waters is an Biography, Drama, History movie with a IMDB sorec of 7.6, a Meta score of 73, and made 11136084 at the box office
# ---------------------
# Rambo III is an Action, Adventure, Thriller movie with a IMDB sorec of 5.8, a Meta score of 36, and made 53715611 at the box office
# ---------------------
# Midway is an Action, Drama, History movie with a IMDB sorec of 6.7, a Meta score of 47, and made 56846802 at the box office
# ---------------------
# Cruel Fixation not found
# ---------------------
# Spies in Disguise is an Animation, Action, Adventure movie with a IMDB sorec of 6.8, a Meta score of 54, and made 66757013 at the box office
# ---------------------
# Gemini Man is an Action, Sci-Fi, Thriller movie with a IMDB sorec of 5.7, a Meta score of 38, and made 48546770 at the box office
# ---------------------
# Black Swan is an Drama, Thriller movie with a IMDB sorec of 8.0, a Meta score of 79, and made 106954678 at the box office
# ---------------------
# Let There Be Light is an Drama movie with a IMDB sorec of 4.4, a Meta score of N/A, and made 7233471 at the box office
# ---------------------
# Men in Black: International is an Action, Adventure, Comedy movie with a IMDB sorec of 5.6, a Meta score of 38, and made 80001807 at the box office
# ---------------------
# The Grudge is an Horror, Mystery, Thriller movie with a IMDB sorec of 5.9, a Meta score of 49, and made 110359362 at the box office
# ---------------------
# Countdown is an Horror, Thriller movie with a IMDB sorec of 5.4, a Meta score of 31, and made 25621766 at the box office
# ---------------------
# Uncut Gems is an Crime, Drama, Thriller movie with a IMDB sorec of 7.4, a Meta score of 91, and made 50023780 at the box office
# ---------------------
# Prospect not found
# ---------------------
# Charlie's Angels is an Action, Adventure, Comedy movie with a IMDB sorec of 5.6, a Meta score of 52, and made 125305545 at the box office
# ---------------------
# Airplane! is an Comedy movie with a IMDB sorec of 7.7, a Meta score of 78, and made 83453539 at the box office
# ---------------------
# Skin not found
# ---------------------
# Pets United not found
# ---------------------
# El Camino: A Breaking Bad Movie not found
# ---------------------
# The Art of Racing in the Rain is an Comedy, Drama, Romance movie with a IMDB sorec of 7.5, a Meta score of 43, and made 26395642 at the box office
# ---------------------
# Dawn of the Dead is an Action, Horror movie with a IMDB sorec of 7.3, a Meta score of 59, and made 59020957 at the box office
# ---------------------
# American Gangster is an Biography, Crime, Drama movie with a IMDB sorec of 7.8, a Meta score of 76, and made 130164645 at the box office
# ---------------------
# Instant Family is an Comedy, Drama movie with a IMDB sorec of 7.3, a Meta score of 57, and made 67363237 at the box office
# ---------------------
# Dora and the Lost City of Gold is an Action, Adventure, Comedy movie with a IMDB sorec of 6.1, a Meta score of 63, and made 60477943 at the box office
# ---------------------
# Lara Croft: Tomb Raider is an Action, Adventure, Fantasy movie with a IMDB sorec of 5.7, a Meta score of 33, and made 131168070 at the box office
# ---------------------
# The Mortuary Collection not found
# ---------------------
# Friday the 13th Part VIII: Jason Takes Manhattan is an Adventure, Horror, Thriller movie with a IMDB sorec of 4.5, a Meta score of 14, and made 14343976 at the box office
# ---------------------
# Code 8 not found
# ---------------------
# Happy Death Day is an Comedy, Horror, Mystery movie with a IMDB sorec of 6.6, a Meta score of 58, and made 55683845 at the box office
# ---------------------
# Mad Max is an Action, Adventure, Sci-Fi movie with a IMDB sorec of 6.8, a Meta score of 73, and made 8750000 at the box office
# ---------------------
# PAW Patrol: Mighty Pups not found
# ---------------------
# Frankenweenie is an Animation, Comedy, Drama movie with a IMDB sorec of 6.9, a Meta score of 74, and made 35291068 at the box office
# ---------------------
# Marriage Story not found
# ---------------------
# Gremlins is an Comedy, Fantasy, Horror movie with a IMDB sorec of 7.3, a Meta score of 70, and made 153642180 at the box office
# ---------------------
# Booksmart is an Comedy movie with a IMDB sorec of 7.1, a Meta score of 84, and made 22680962 at the box office
# ---------------------
# Mystic River is an Crime, Drama, Mystery movie with a IMDB sorec of 7.9, a Meta score of 84, and made 90135191 at the box office
# ---------------------
# Upgrade is an Action, Sci-Fi, Thriller movie with a IMDB sorec of 7.5, a Meta score of 67, and made 11977130 at the box office
# ---------------------
# The Hustle is an Comedy, Crime movie with a IMDB sorec of 5.4, a Meta score of 35, and made 35417038 at the box office
# ---------------------
# Night Hunter not found
# ---------------------
# Klaus not found
# ---------------------
# The Report not found
# ---------------------
# The Little Mermaid Live! not found
# ---------------------
# Bombshell is an Biography, Drama movie with a IMDB sorec of 6.8, a Meta score of 64, and made 31762808 at the box office
# ---------------------
# The Jack in the Box not found
# ---------------------
# Good Boys is an Adventure, Comedy movie with a IMDB sorec of 6.7, a Meta score of N/A, and made 83140306 at the box office
# ---------------------
# The Vigil is an Horror, Mystery, Thriller movie with a IMDB sorec of 5.8, a Meta score of 69, and made 50439 at the box office
# ---------------------
# Collateral is an Action, Crime, Drama movie with a IMDB sorec of 7.5, a Meta score of 71, and made 101005703 at the box office
# ---------------------
# Triple Threat is an Action, Thriller movie with a IMDB sorec of 5.6, a Meta score of 60, and made 76289 at the box office
# ---------------------
# Haunt not found
# ---------------------
# Blue Story not found
# ---------------------
# The Lego Movie 2: The Second Part is an Animation, Action, Adventure movie with a IMDB sorec of 6.6, a Meta score of 65, and made 105956290 at the box office
# ---------------------
# Friday the 13th Part VII: The New Blood is an Horror, Thriller movie with a IMDB sorec of 5.2, a Meta score of 13, and made 19170001 at the box office
# ---------------------
# Togo not found
# ---------------------
# Teen Titans Go! vs. Teen Titans not found
# ---------------------
# Color Out of Space is an Horror, Mystery, Sci-Fi movie with a IMDB sorec of 6.2, a Meta score of 70, and made 765561 at the box office
# ---------------------
# Death Wish is an Action, Crime, Drama movie with a IMDB sorec of 6.3, a Meta score of 31, and made 34017028 at the box office
# ---------------------
# Going in Style is an Comedy, Crime movie with a IMDB sorec of 6.6, a Meta score of 50, and made 45018541 at the box office
# ---------------------
# Lady and the Tramp is an Animation, Adventure, Comedy movie with a IMDB sorec of 7.3, a Meta score of 78, and made 93602326 at the box office
# ---------------------
# Stand by Me is an Adventure, Drama movie with a IMDB sorec of 8.1, a Meta score of 75, and made 52287414 at the box office
# ---------------------
# Meet the Parents is an Comedy, Romance movie with a IMDB sorec of 7.0, a Meta score of 73, and made 166244045 at the box office
# ---------------------
# Monster Trucks is an Action, Adventure, Comedy movie with a IMDB sorec of 5.6, a Meta score of 41, and made 33370166 at the box office
# ---------------------
# 47 Meters Down: Uncaged is an Adventure, Drama, Horror movie with a IMDB sorec of 5.0, a Meta score of 43, and made 22260900 at the box office
# ---------------------
# The Nice Guys is an Action, Comedy, Crime movie with a IMDB sorec of 7.3, a Meta score of 70, and made 36261763 at the box office
# ---------------------
# Butch Cassidy and the Sundance Kid is an Biography, Crime, Drama movie with a IMDB sorec of 8.0, a Meta score of 66, and made 102308889 at the box office
# ---------------------
# Love Actually is an Comedy, Drama, Romance movie with a IMDB sorec of 7.6, a Meta score of 55, and made 59696144 at the box office
# ---------------------
# Scooby-Doo! Return to Zombie Island not found
# ---------------------
# Wonder Park is an Animation, Adventure, Comedy movie with a IMDB sorec of 5.8, a Meta score of 45, and made 45216793 at the box office
# ---------------------
# Seven Years in Tibet is an Adventure, Biography, Drama movie with a IMDB sorec of 7.1, a Meta score of 55, and made 37957682 at the box office
# ---------------------
# The King not found
# ---------------------
# The Kill Team not found
# ---------------------
# Escape Plan: The Extractors not found
# ---------------------
# Cold Blood is an Action, Thriller movie with a IMDB sorec of 4.6, a Meta score of 25, and made 5083 at the box office
# ---------------------
# Mermaid Down not found
# ---------------------
# Hustlers is an Comedy, Crime, Drama movie with a IMDB sorec of 6.3, a Meta score of 79, and made 104963598 at the box office
# ---------------------
# Captive State is an Action, Horror, Sci-Fi movie with a IMDB sorec of 6.0, a Meta score of 54, and made 5958315 at the box office
# ---------------------
# Trouble not found
# ---------------------
# Benny Loves You not found
# ---------------------
# Shaft is an Action, Crime, Thriller movie with a IMDB sorec of 6.0, a Meta score of 50, and made 70334258 at the box office
# ---------------------
# Bilby not found
# ---------------------
# Rocketman is an Biography, Drama, Musical movie with a IMDB sorec of 7.3, a Meta score of 69, and made 96368160 at the box office
# ---------------------
# Waves is an Drama, Romance, Sport movie with a IMDB sorec of 7.5, a Meta score of 80, and made 1658790 at the box office
# ---------------------
# 21 Bridges is an Action, Crime, Drama movie with a IMDB sorec of 6.6, a Meta score of 51, and made 28539757 at the box office
# ---------------------
# Unleashed is an Action, Crime, Drama movie with a IMDB sorec of 7.0, a Meta score of 58, and made 24537621 at the box office
# ---------------------
# Child's Play is an Horror, Thriller movie with a IMDB sorec of 6.6, a Meta score of 58, and made 33244684 at the box office
# ---------------------
# Antrum not found
# ---------------------
# Dangerous Beauty is an Biography, Drama, Romance movie with a IMDB sorec of 7.1, a Meta score of N/A, and made 4553271 at the box office
# ---------------------
# Long Shot is an Comedy, Romance movie with a IMDB sorec of 6.8, a Meta score of 67, and made 30316271 at the box office
# ---------------------
# Lying and Stealing not found
# ---------------------
# StarDog and TurboCat is an Animation, Comedy, Family movie with a IMDB sorec of 5.1, a Meta score of N/A, and made 80490 at the box office
# ---------------------
# Fantasia 2000 is an Animation, Family, Fantasy movie with a IMDB sorec of 7.1, a Meta score of 59, and made 60655420 at the box office
# ---------------------
# Little is an Comedy, Drama movie with a IMDB sorec of 7.8, a Meta score of 80, and made 59891098 at the box office
# ---------------------
# The Healer not found
# ---------------------
# The Courier is an Drama, History, Thriller movie with a IMDB sorec of 7.2, a Meta score of 65, and made 6613432 at the box office
# ---------------------
# The Informer is an Action, Crime, Drama movie with a IMDB sorec of 6.6, a Meta score of 61, and made 300460 at the box office
# ---------------------
# The Outpost is an Action, Drama, History movie with a IMDB sorec of 6.8, a Meta score of 71, and made 186635 at the box office
# ---------------------
# Motherless Brooklyn is an Crime, Drama, Mystery movie with a IMDB sorec of 6.8, a Meta score of 60, and made 9277736 at the box office
# ---------------------
# Hotel Mumbai is an Action, Drama, History movie with a IMDB sorec of 7.6, a Meta score of 62, and made 9651611 at the box office
# ---------------------
# Doom: Annihilation not found
# ---------------------
# Yesterday is an Comedy, Fantasy, Music movie with a IMDB sorec of 6.8, a Meta score of 55, and made 73286650 at the box office
# ---------------------
# Amityville II: The Possession is an Horror movie with a IMDB sorec of 5.5, a Meta score of 34, and made 12534817 at the box office
# ---------------------
# The Rescuers is an Animation, Adventure, Comedy movie with a IMDB sorec of 6.9, a Meta score of 74, and made 71215869 at the box office
# ---------------------
# Trial by Fire is an Biography, Drama movie with a IMDB sorec of 7.1, a Meta score of 51, and made 148504 at the box office
# ---------------------
# Modern Times is an Comedy, Drama, Romance movie with a IMDB sorec of 8.5, a Meta score of 96, and made 163577 at the box office
# ---------------------
# Playing with Fire is an Comedy, Family movie with a IMDB sorec of 5.1, a Meta score of 24, and made 44451847 at the box office
# ---------------------
# The Queen's Corgi not found
# ---------------------
# Jexi is an Comedy, Romance, Sci-Fi movie with a IMDB sorec of 6.0, a Meta score of 39, and made 6546159 at the box office
# ---------------------
# The Goldfinch is an Drama movie with a IMDB sorec of 6.4, a Meta score of 40, and made 5332621 at the box office
# ---------------------
# Knocked Up is an Comedy, Romance movie with a IMDB sorec of 6.9, a Meta score of 85, and made 148768917 at the box office
# ---------------------
# Ad Astra is an Adventure, Drama, Mystery movie with a IMDB sorec of 6.5, a Meta score of 80, and made 50188370 at the box office
# ---------------------
# Harriet is an Action, Biography, Drama movie with a IMDB sorec of 6.7, a Meta score of 66, and made 43082155 at the box office
# ---------------------
# The Elephant Man is an Biography, Drama movie with a IMDB sorec of 8.2, a Meta score of 78, and made 26010864 at the box office
# ---------------------
# UglyDolls is an Animation, Adventure, Comedy movie with a IMDB sorec of 5.1, a Meta score of 39, and made 20150241 at the box office
# ---------------------
# Missing Link is an Animation, Adventure, Comedy movie with a IMDB sorec of 6.7, a Meta score of 68, and made 16649539 at the box office
# ---------------------
# Wonder Woman: Bloodlines not found
# ---------------------
# Abigail not found
# ---------------------
# The Great Dictator not found
# ---------------------
# A Beautiful Day in the Neighborhood is an Biography, Drama movie with a IMDB sorec of 7.2, a Meta score of 80, and made 61704055 at the box office
# ---------------------
# Apollo 13 is an Adventure, Drama, History movie with a IMDB sorec of 7.7, a Meta score of 77, and made 173837933 at the box office
# ---------------------
# Grand Isle not found
# ---------------------
# In the Tall Grass not found
# ---------------------
# How to Train Your Dragon: Snoggletog Log not found
# ---------------------
# Guns Akimbo not found
# ---------------------
# Fright Night is an Comedy, Horror movie with a IMDB sorec of 6.4, a Meta score of 64, and made 18302607 at the box office
# ---------------------
# Dragged Across Concrete not found
# ---------------------
# A Score to Settle not found
# ---------------------
# Jarhead: Law of Return not found
# ---------------------
# Easy Rider is an Adventure, Drama movie with a IMDB sorec of 7.3, a Meta score of 85, and made 123276 at the box office
# ---------------------
# Halloween: Resurrection is an Horror, Thriller movie with a IMDB sorec of 3.9, a Meta score of 19, and made 30354442 at the box office
# ---------------------
# Serenity is an Action, Adventure, Sci-Fi movie with a IMDB sorec of 7.8, a Meta score of 74, and made 25514517 at the box office
# ---------------------
# The Hole in the Ground is an Drama, Horror, Mystery movie with a IMDB sorec of 5.6, a Meta score of 63, and made 21072 at the box office
# ---------------------
# Synchronic is an Drama, Horror, Mystery movie with a IMDB sorec of 6.2, a Meta score of 64, and made 636673 at the box office
# ---------------------
# Away not found
# ---------------------
# The Two Popes not found
# ---------------------
# Ophelia is an Drama, Romance, Thriller movie with a IMDB sorec of 6.5, a Meta score of 60, and made 50722 at the box office
# ---------------------
# The Room is an Drama movie with a IMDB sorec of 3.6, a Meta score of 9, and made 549602 at the box office
# ---------------------
# A Royal Winter not found
# ---------------------
# Galaxy Quest is an Adventure, Comedy, Sci-Fi movie with a IMDB sorec of 7.4, a Meta score of 70, and made 71583916 at the box office
# ---------------------
# The Professor and the Madman not found
# ---------------------
# Driven is an Action, Drama, Sport movie with a IMDB sorec of 4.6, a Meta score of 29, and made 32720065 at the box office
# ---------------------
# Sea Fever not found
# ---------------------
# 211 not found
# ---------------------
# Saint Maud not found
# ---------------------
# 47 Meters Down is an Adventure, Drama, Horror movie with a IMDB sorec of 5.6, a Meta score of 52, and made 44307191 at the box office
# ---------------------
# A Cinderella Story: Christmas Wish not found
# ---------------------
# The Intern - A Summer of Lust not found
# ---------------------
# Official Secrets is an Biography, Crime, Drama movie with a IMDB sorec of 7.3, a Meta score of 63, and made 1988546 at the box office
# ---------------------
# Chef is an Adventure, Comedy, Drama movie with a IMDB sorec of 7.3, a Meta score of 68, and made 31424003 at the box office
# ---------------------
# You Were Never Really Here is an Crime, Drama movie with a IMDB sorec of 6.7, a Meta score of 84, and made 2528078 at the box office
# ---------------------
# Stuber is an Action, Comedy, Crime movie with a IMDB sorec of 6.2, a Meta score of 42, and made 22370452 at the box office
# ---------------------
# At Eternity's Gate is an Biography, Drama, History movie with a IMDB sorec of 6.9, a Meta score of 76, and made 2294915 at the box office
# ---------------------
# Bent is an Drama, History, Romance movie with a IMDB sorec of 7.1, a Meta score of N/A, and made 496059 at the box office
# ---------------------
# Eli not found
# ---------------------
# Last Christmas is an Comedy, Drama, Fantasy movie with a IMDB sorec of 6.5, a Meta score of 50, and made 35150750 at the box office
# ---------------------
# The Nightingale is an Adventure, Drama, Thriller movie with a IMDB sorec of 7.3, a Meta score of 77, and made 400209 at the box office
# ---------------------
# Black and Blue is an Action, Thriller movie with a IMDB sorec of 6.4, a Meta score of 54, and made 22055313 at the box office
# ---------------------
# The Intruder is an Horror, Thriller movie with a IMDB sorec of 5.6, a Meta score of 39, and made 35419122 at the box office
# ---------------------
# Palm Swings not found
# ---------------------
# Sator not found
# ---------------------
# 7500 not found
# ---------------------
# Buddy Games is an Comedy movie with a IMDB sorec of 4.8, a Meta score of 22, and made 405904 at the box office
# ---------------------
# Agatha and the Truth of Murder not found
# ---------------------
# The Aeronauts not found
# ---------------------
# The Neon Demon is an Horror, Thriller movie with a IMDB sorec of 6.1, a Meta score of 51, and made 1333124 at the box office
# ---------------------
# The Dead Don't Die is an Comedy, Fantasy, Horror movie with a IMDB sorec of 5.4, a Meta score of 53, and made 6563605 at the box office
# ---------------------
# I Still See You is an Fantasy, Horror, Sci-Fi movie with a IMDB sorec of 5.8, a Meta score of 31, and made 1359 at the box office
# ---------------------
# My Own Private Idaho is an Drama movie with a IMDB sorec of 7.0, a Meta score of 77, and made 6401336 at the box office
# ---------------------
# A Christmas Prince: The Royal Baby not found
# ---------------------
# The Peanut Butter Falcon is an Adventure, Comedy, Drama movie with a IMDB sorec of 7.6, a Meta score of 70, and made 20457151 at the box office
# ---------------------
# King of Thieves is an Biography, Crime, Drama movie with a IMDB sorec of 5.5, a Meta score of 48, and made 7518 at the box office
# ---------------------
# Can You Keep a Secret? not found
# ---------------------
# 3 from Hell is an Action, Horror movie with a IMDB sorec of 5.4, a Meta score of 50, and made 2172949 at the box office
# ---------------------
# Ma is an Horror, Mystery, Thriller movie with a IMDB sorec of 5.6, a Meta score of 53, and made 45896028 at the box office
# ---------------------
# Primal: Tales of Savagery not found
# ---------------------
# The Poison Rose not found
# ---------------------
# Burn not found
# ---------------------
# The Aftermath is an Drama, Romance, War movie with a IMDB sorec of 6.3, a Meta score of 43, and made 1618497 at the box office
# ---------------------
# Danger Close: The Battle of Long Tan not found
# ---------------------
# Blue Jasmine is an Comedy, Drama movie with a IMDB sorec of 7.3, a Meta score of 78, and made 33405481 at the box office
# ---------------------
# Darlin' not found
# ---------------------
# Trauma Center not found
# ---------------------
# Avengement not found
# ---------------------
# Anna and the Apocalypse is an Comedy, Horror, Musical movie with a IMDB sorec of 6.0, a Meta score of 63, and made 545597 at the box office
# ---------------------
# A Shaun the Sheep Movie: Farmageddon not found
# ---------------------
# Santa Sangre not found
# ---------------------
# Mary not found
# ---------------------
# A Hidden Life is an Biography, Drama, Romance movie with a IMDB sorec of 7.4, a Meta score of 78, and made 1730597 at the box office
# ---------------------
# Manou the Swift not found
# ---------------------
# Gnome Alone not found
# ---------------------
# The Banana Splits Movie not found
# ---------------------
# Wounds not found
# ---------------------
# Inside Man: Most Wanted not found
# ---------------------
# Backdraft 2 not found
# ---------------------
# Dolemite Is My Name not found
# ---------------------
# Little Italy is an Comedy, Romance movie with a IMDB sorec of 5.7, a Meta score of 28, and made 990230 at the box office
# ---------------------
# The Watcher not found
# ---------------------
# A Private War is an Biography, Drama, War movie with a IMDB sorec of 6.7, a Meta score of 75, and made 1633208 at the box office
# ---------------------
# The Vanishing not found
# ---------------------
# Three Identical Strangers is an Documentary, Biography, Drama movie with a IMDB sorec of 7.6, a Meta score of 81, and made 12320845 at the box office
# ---------------------
# Primal not found
# ---------------------
# The Convent not found
# ---------------------
# The Humanity Bureau not found
# ---------------------
# Apollo 11 is an Documentary, History movie with a IMDB sorec of 8.1, a Meta score of 88, and made 9039891 at the box office
# ---------------------
# Let It Snow not found
# ---------------------
# Daughter of the Wolf not found
# ---------------------
# The Good Liar is an Crime, Drama, Mystery movie with a IMDB sorec of 6.7, a Meta score of 55, and made 17156058 at the box office
# ---------------------
# Race is an Biography, Drama, Sport movie with a IMDB sorec of 7.1, a Meta score of 56, and made 19206207 at the box office
# ---------------------
# The Personal History of David Copperfield is an Comedy, Drama movie with a IMDB sorec of 6.4, a Meta score of 77, and made 1876298 at the box office
# ---------------------
# Playmobil: The Movie is an Animation, Adventure, Comedy movie with a IMDB sorec of 4.9, a Meta score of 25, and made 1115008 at the box office
# ---------------------
# The War of the Roses is an Comedy, Romance movie with a IMDB sorec of 6.8, a Meta score of 79, and made 86888546 at the box office
# ---------------------
# Tolkien is an Biography, Drama, Romance movie with a IMDB sorec of 6.8, a Meta score of 48, and made 4535154 at the box office
# ---------------------
# Honey Boy is an Drama movie with a IMDB sorec of 7.2, a Meta score of 73, and made 3012615 at the box office
# ---------------------
# Our Friend is an Drama, Romance movie with a IMDB sorec of 7.3, a Meta score of 57, and made 663725 at the box office
# ---------------------
# Paw Patrol: Ready, Race, Rescue! not found
# ---------------------
# Running with the Devil not found
# ---------------------
# The Wedding Year not found
# ---------------------
# Smokey and the Bandit is an Action, Adventure, Comedy movie with a IMDB sorec of 7.0, a Meta score of 50, and made 126737428 at the box office
# ---------------------
# In Fabric not found
# ---------------------
# The Last Full Measure is an Drama, War movie with a IMDB sorec of 6.8, a Meta score of 51, and made 2949212 at the box office
# ---------------------
# Money Monster is an Crime, Drama, Mystery movie with a IMDB sorec of 6.5, a Meta score of 55, and made 41012075 at the box office
# ---------------------
# Richard Jewell is an Biography, Crime, Drama movie with a IMDB sorec of 7.5, a Meta score of 68, and made 22345542 at the box office
# ---------------------
# Ride Like a Girl not found
# ---------------------
# Wayne's World is an Comedy, Music movie with a IMDB sorec of 7.0, a Meta score of 57, and made 121697323 at the box office
# ---------------------
# Arctic Dogs is an Animation, Adventure, Comedy movie with a IMDB sorec of 4.8, a Meta score of 28, and made 5801249 at the box office
# ---------------------
# The Vast of Night not found
# ---------------------
# Angel of Mine not found
# ---------------------
# The Farewell is an Comedy, Drama movie with a IMDB sorec of 7.5, a Meta score of 89, and made 17695781 at the box office
# ---------------------
# I Am Mother not found
# ---------------------
# The Current War is an Biography, Drama, History movie with a IMDB sorec of 6.5, a Meta score of 55, and made 5979540 at the box office
# ---------------------
# Greed not found
# ---------------------
# The Burnt Orange Heresy is an Drama, Thriller movie with a IMDB sorec of 6.1, a Meta score of 57, and made 144201 at the box office
# ---------------------
# Time Freak is an Comedy, Drama, Romance movie with a IMDB sorec of 5.8, a Meta score of N/A, and made 10003 at the box office
# ---------------------
# Maurice is an Drama, Romance movie with a IMDB sorec of 7.7, a Meta score of 75, and made 2484230 at the box office
# ---------------------
# Downton Abbey not found
# ---------------------
# The Laundromat not found
# ---------------------
# Cats is an Comedy, Drama, Family movie with a IMDB sorec of 2.8, a Meta score of 32, and made 27166770 at the box office
# ---------------------
# Jay and Silent Bob Reboot is an Action, Adventure, Comedy movie with a IMDB sorec of 5.6, a Meta score of 46, and made 4589490 at the box office
# ---------------------
# The Breadwinner is an Animation, Drama, Family movie with a IMDB sorec of 7.7, a Meta score of 78, and made 313215 at the box office
# ---------------------
# How to Talk to Girls at Parties is an Comedy, Music, Romance movie with a IMDB sorec of 5.7, a Meta score of 50, and made 84809 at the box office
# ---------------------
# A Million Little Pieces not found
# ---------------------
# Zoo not found
# ---------------------
# Little Monsters not found
# ---------------------
# Waiting for the Barbarians not found
# ---------------------
# Where'd You Go, Bernadette is an Comedy, Drama movie with a IMDB sorec of 6.5, a Meta score of 51, and made 9198356 at the box office
# ---------------------
# Line of Duty not found
# ---------------------
# Lego DC Batman: Family Matters not found
# ---------------------
# The Cleansing Hour not found
# ---------------------
# Courage Under Fire is an Action, Drama, Mystery movie with a IMDB sorec of 6.6, a Meta score of 77, and made 59031057 at the box office
# ---------------------
# The Knight Before Christmas not found
# ---------------------
# The Kitchen is an Action, Crime, Drama movie with a IMDB sorec of 5.6, a Meta score of 35, and made 12180032 at the box office
# ---------------------
# The Hummingbird Project is an Drama, Thriller movie with a IMDB sorec of 6.2, a Meta score of 58, and made 371784 at the box office
# ---------------------
# Marathon Man is an Crime, Drama, Thriller movie with a IMDB sorec of 7.4, a Meta score of 64, and made 21709020 at the box office
# ---------------------
# Dreamland not found
# ---------------------
# Kursk not found
# ---------------------
# Drunk Parents not found
# ---------------------
# Tell It to the Bees not found
# ---------------------
# The Last Dragonslayer not found
# ---------------------
# The Art of Self-Defense is an Action, Comedy, Crime movie with a IMDB sorec of 6.6, a Meta score of 65, and made 2410914 at the box office
# ---------------------
# Tucker: The Man and His Dream is an Biography, Comedy, Drama movie with a IMDB sorec of 6.9, a Meta score of 74, and made 19656113 at the box office
# ---------------------
# Bad Education is an Crime, Drama movie with a IMDB sorec of 7.4, a Meta score of 81, and made 5284284 at the box office
# ---------------------
# Domino is an Action, Biography, Crime movie with a IMDB sorec of 5.9, a Meta score of 36, and made 10169202 at the box office
# ---------------------
# Vita & Virginia is an Biography, Drama, Romance movie with a IMDB sorec of 5.8, a Meta score of 43, and made 42741 at the box office
# ---------------------
# Air Strike not found
# ---------------------
# Ploey: You Never Fly Alone not found
# ---------------------
# Blood Simple is an Crime, Drama, Thriller movie with a IMDB sorec of 7.6, a Meta score of 83, and made 3851855 at the box office
# ---------------------
# 10 Minutes Gone not found
# ---------------------
# The Death & Life of John F. Donovan is an Action, Adventure, Sci-Fi movie with a IMDB sorec of 6.2, a Meta score of 50, and made 58032443 at the box office
# ---------------------
# Gloria Bell is an Comedy, Drama, Music movie with a IMDB sorec of 6.3, a Meta score of 79, and made 5611123 at the box office
# ---------------------
# VFW not found
# ---------------------
# Crown Vic is an Action, Adventure, Crime movie with a IMDB sorec of 6.4, a Meta score of 47, and made 3868 at the box office
# ---------------------
# Head Full of Honey not found
# ---------------------
# Teen Spirit is an Drama, Music movie with a IMDB sorec of 6.1, a Meta score of 57, and made 441366 at the box office
# ---------------------
# Can You Ever Forgive Me? is an Biography, Comedy, Crime movie with a IMDB sorec of 7.1, a Meta score of 87, and made 8803865 at the box office
# ---------------------
# The Beach Bum is an Comedy movie with a IMDB sorec of 5.5, a Meta score of 55, and made 3502600 at the box office
# ---------------------
# The Man Who Invented Christmas is an Biography, Comedy, Drama movie with a IMDB sorec of 7.0, a Meta score of 60, and made 5676486 at the box office
# ---------------------
# Sleeping With My Student not found
# ---------------------
# Wasp Network not found
# ---------------------
# Noelle not found
# ---------------------
# Paradise Hills not found
# ---------------------
# Kim Possible not found
# ---------------------
# Pope Francis: A Man of His Word is an Documentary, Biography movie with a IMDB sorec of 6.5, a Meta score of 63, and made 2008385 at the box office
# ---------------------
# High Strung Free Dance is an Music, Romance movie with a IMDB sorec of 6.8, a Meta score of 43, and made 83891 at the box office
# ---------------------
# The Wishmas Tree not found
# ---------------------
# Uncanny Annie not found
# ---------------------
# Sweetheart not found
# ---------------------
# Judy is an Biography, Drama, Music movie with a IMDB sorec of 6.8, a Meta score of 66, and made 24313888 at the box office
# ---------------------
# Les MisÃ©rables not found
# ---------------------
# An Affair to Die For not found
# ---------------------
# Queen & Slim not found
# ---------------------
# Our Kind of Traitor is an Crime, Drama, Thriller movie with a IMDB sorec of 6.2, a Meta score of 57, and made 3153157 at the box office
# ---------------------
# RBG is an Documentary, Biography movie with a IMDB sorec of 7.6, a Meta score of 71, and made 14051361 at the box office
# ---------------------
# Life on the Line not found
# ---------------------
# Blood Quantum not found
# ---------------------
# The Maiden Heist not found
# ---------------------
# Killers Anonymous not found
# ---------------------
# Air Buddies not found
# ---------------------
# Eighth Grade is an Comedy, Drama movie with a IMDB sorec of 7.4, a Meta score of 89, and made 13539709 at the box office
# ---------------------
# Lucy in the Sky is an Drama, Romance, Sci-Fi movie with a IMDB sorec of 4.9, a Meta score of 36, and made 319976 at the box office
# ---------------------
# Needful Things is an Crime, Drama, Fantasy movie with a IMDB sorec of 6.2, a Meta score of 43, and made 15185672 at the box office
# ---------------------
# Invasion: Planet Earth not found
# ---------------------
# Lucky Day not found
# ---------------------
# Badland not found
# ---------------------
# Seberg is an Biography, Drama, Thriller movie with a IMDB sorec of 5.9, a Meta score of 54, and made 434702 at the box office
# ---------------------
# Dirty Sexy Saint not found
# ---------------------
# Blackbird not found
# ---------------------
# Permission not found
# ---------------------
# The Gallows Act II not found
# ---------------------
# Killerman is an Action, Crime, Thriller movie with a IMDB sorec of 5.4, a Meta score of 42, and made 291477 at the box office
# ---------------------
# Tammy and the T-Rex not found
# ---------------------
# Deadwood: The Movie not found
# ---------------------
# The Dare not found
# ---------------------
# Blinded by the Light is an Comedy, Drama, Music movie with a IMDB sorec of 6.9, a Meta score of 71, and made 11901145 at the box office
# ---------------------
# Semper Fi not found
# ---------------------
# The Professor not found
# ---------------------
# The Guernsey Literary & Potato Peel Pie Society not found
# ---------------------
# A Call to Spy is an Biography, Crime, Drama movie with a IMDB sorec of 6.6, a Meta score of 65, and made 159014 at the box office
# ---------------------
# The Greatest Show on Earth is an Drama, Family, Romance movie with a IMDB sorec of 6.6, a Meta score of N/A, and made 36000000 at the box office
# ---------------------
# Steven Universe: The Movie: Behind the Curtain not found
# ---------------------
# The Mustang is an Drama movie with a IMDB sorec of 6.8, a Meta score of 77, and made 5043620 at the box office
# ---------------------
# The Sun Is Also a Star is an Drama, Music, Romance movie with a IMDB sorec of 5.9, a Meta score of 52, and made 4950029 at the box office
# ---------------------
# Hollow Point not found
# ...
# ---------------------
# The Great NHS Heist not found
# ---------------------
# Killing Lionel not found
# ---------------------
# Swipe not found
# ---------------------
# Lost Pharaohs of the Nile not found
# ---------------------
# The House on Devil's Road not found
# ---------------------
# Jamaica Tapes not found
# ---------------------
# Is This a Date not found
# ---------------------
# At the Coliseum Deluxe not found
# ---------------------
# Catfight not found
# ---------------------
# La Trifulca I. Five Billion Dollar. A Trilogy not found
# ---------------------
# Tales of Found Footage not found
# ---------------------
# Scorpions: Rock In Rio not found
# ---------------------
# The People and Their Emperor not found
# ---------------------
# The Ruin not found
# ---------------------
# The Bush Knife not found
# ---------------------
# Before You Know It is an Comedy, Drama movie with a IMDB sorec of 5.3, a Meta score of 61, and made 151507 at the box office
# ---------------------
# To Catch a Dream not found
# ---------------------
# Beauty and Ruin not found
# ---------------------
# Gauguin: A Dangerous Life not found
# ---------------------
# OMD: Souvenir not found
# ---------------------
# Un cuento sin ti not found
# ---------------------
# What Madness not found
# ---------------------
# E.M. Forster: His Longest Journey not found
# ---------------------
# Still Life in Lodz not found
# ---------------------
# Imaginary Friend not found
# ---------------------
# Billy Connolly: The Sex Life of Bandages not found
# ---------------------
# The Wrong Todd not found
# ---------------------
# Like Turtles not found
# ---------------------
# The Dial Tone of Doom not found
# ---------------------
# Domestic Warfare not found
# ---------------------
# Rip to the Rescue! not found
# ---------------------
# The Who: The Night That Changed Rock not found
# ---------------------
# De grote dataroof not found
# ---------------------
# JOY is an Biography, Drama movie with a IMDB sorec of 6.6, a Meta score of 56, and made 56451232 at the box office
# ---------------------
# Submission Underground 10 not found
# ---------------------
# Almost Famous: Kim I Am not found
# ---------------------
# Z = |Z/Zâ€¢Z-1 mod 2|-1: Lavender Town Syndrome not found
# ---------------------
# This Camera is Broken not found
# ---------------------
# What Happened to Henry? not found
# ---------------------
# Matches not found
# ---------------------
# Greatest Ever Christmas Movies not found
# ---------------------
# EXT.NUIT not found
# ---------------------
# Flood not found
# ---------------------
# Our Bodies Our Doctors not found
# ---------------------
# The Last American Colony: One Man's Revolution not found
# ---------------------
# Seaver not found
# ---------------------
# Dressing Up for Nobody not found
# ---------------------
# Jack's Shed not found
# ---------------------
# A Piece of Chocolate not found
# ---------------------
# Pleasure Seekers not found
# ---------------------
# Handwritten Theatre: Note the Relationship Between the Two Seated Figures in the Booth not found
# ---------------------
# Secret Nights not found
# ---------------------
# Vilified Banker not found
# ---------------------
# Emmanuel and Me not found
# ---------------------
# The Essence: Part II not found
# ---------------------
# AYO SCHIEF not found
# ---------------------
# Who You Are not found
# ---------------------
# Hard Quiz Celebrity Special not found
# ---------------------
# Posbus 1 not found
# ---------------------
# Domo Is Put in the Mail not found
# ---------------------
# Making King Henry V not found
# ---------------------
# Me, My Dog, and I not found
# ---------------------
# Mutism not found
# ---------------------
# DJ Slay not found
# ---------------------
# The Company You Keep is an Drama, Thriller movie with a IMDB sorec of 6.4, a Meta score of 57, and made 5133027 at the box office
# ---------------------
# The Housemaids not found
# ---------------------
# Apoorva Souhrudhangal not found
# ---------------------
# Polterguests not found
# ---------------------
# Eden not found
# ---------------------
# Vlad Has a Nice Hat not found
# ---------------------
# Crescendo not found
# ---------------------
# Project Christmas Joy not found
# ---------------------
# Peter Kay Comedy Genius not found
# ---------------------
# Renchik not found
# ---------------------
# One Woman Man not found
# ---------------------
# GUILT not found
# ---------------------
# Labor Relations not found
# ---------------------
# STRANGERS is an Crime, Drama, Film-Noir movie with a IMDB sorec of 7.9, a Meta score of 88, and made 26597 at the box office
# ---------------------
# Harvey's Last Night on the Avenue not found
# ---------------------
# Incognita not found
# ---------------------
# A Journey not found
# ---------------------
# The Doors Between Us not found
# ---------------------
# (S)he Said that not found
# ---------------------
# Week in Paradise not found
# ---------------------
# Tasteful Nudes not found
# ---------------------
# Rescue Me: A Home 4 Spot not found
# ---------------------
# Goin South is an Comedy, Romance, Western movie with a IMDB sorec of 6.2, a Meta score of 52, and made 7435671 at the box office
# ---------------------
# Dido: In Concert at BBC's Maida Vale Studios not found
# ---------------------
# Confluence not found
# ---------------------
# Hellthy not found
# ---------------------
# Jim Smith: Live From Perth not found
# ---------------------
# Land of Dreams not found
# ---------------------
# Hounded not found
# ---------------------
# L'italiano che inventÃ² il cinema not found
# ---------------------
# Christy not found
# ---------------------
# Gladiators on Wheels not found
# ---------------------
# The Fall of the Berlin Wall with John Simpson not found
# ---------------------
# A Lenda do Galo not found
# ---------------------
# The Unknown Tour not found
# ---------------------
# Still Standing not found
# ---------------------
# Helloween: Rock In Rio 2019 not found
# ---------------------
# We Three Queens not found
# ---------------------
# Humblebrag not found
# ---------------------
# Harry Kiri not found
# ---------------------
# Maya not found
# ---------------------
# Watched not found
# ---------------------
# Beethoven: live at Roma Street Parkland not found
# ---------------------
# #StillGotIt?! not found
# ---------------------
# Unpacked not found
# ---------------------
# Around the Corner not found
# ---------------------
# Number Two not found
# ---------------------
# Modulation Nowhere not found
# ---------------------
# Dear Friend not found
# ---------------------
# Weasels: Feisty and Fearless not found
# ---------------------
# Appurtenance not found
# ---------------------
# The Eternal Wife not found
# ---------------------
# Spring Cleaning not found
# ---------------------
# Revenge not found
# ---------------------
# Home Fires not found
# ---------------------
# Suspect is an Crime, Drama, Thriller movie with a IMDB sorec of 6.6, a Meta score of 53, and made 18782400 at the box office
# ---------------------
# data-verse 2 not found
# ---------------------
# FAQIR not found
# ---------------------
# Tommaso Ciampa: blackHEART not found
# ---------------------
# The Warrior Tradition not found
# ---------------------
# Healthy Seas: Mission to Santorini not found
# ---------------------
# Opening the Mind not found
# ---------------------
# Pharmacopeia not found
# ---------------------
# Angie Lemaire not found
# ---------------------
# Dead Packet not found
# ---------------------
# The Storm not found
# ---------------------
# Computer Hackers not found
# ---------------------
# Second Thoughts not found
# ---------------------
# Fix is an Drama movie with a IMDB sorec of 6.0, a Meta score of 31, and made 9890 at the box office
# ---------------------
# Disconnect is an Drama, Thriller movie with a IMDB sorec of 7.5, a Meta score of 64, and made 1436900 at the box office
# ---------------------
# EVE SHE-1: Ace Of EVE 2019 - Day 1: Show 1 not found
# ---------------------
# A COLD CASE: Based On True Jack Boyz Stories not found
# ---------------------
# I'm Not Ready not found
# ---------------------
# Addicted: America's Opioid Crisis not found
# ---------------------
# Elemental Correspondence not found
# ---------------------
# What Will You Do Now, John? not found
# ---------------------
# The Worst Thing not found
# ---------------------
# Lost Eye not found
# ---------------------
# Mr. Ticklez not found
# ---------------------
# Deux Oiseaux not found
# ---------------------
# Salvation not found
# ---------------------
# Vicious Are the Ways of a Witch not found
# ---------------------
# Maya not found
# ---------------------
# Ninja Dream not found
# ---------------------
# STARRCAST IV: Crockett not found
# ---------------------
# Primer is an Drama, Sci-Fi, Thriller movie with a IMDB sorec of 6.8, a Meta score of 68, and made 424760 at the box office
# ---------------------
# Abstract Horror not found
# ---------------------
# Welcome to the Horror Show: Ping not found
# ---------------------
# Whack Job not found
# ---------------------
# Out of Tune not found
# ---------------------
# New Year not found
# ---------------------
# Flower Punk not found
# ---------------------
# Uncivilized not found
# ---------------------
# Karman not found
# ---------------------
# Cybernetic Showdown not found
# ---------------------
# Reflections on Witness not found
# ---------------------
# Standing Above the Clouds not found
# ---------------------
# One Last Monster not found
# ---------------------
# Across, Beyond, and Over not found
# ---------------------
# Field of Valor: Air Activities of Texas not found
# ---------------------
# The Uncanny Valley not found
# ---------------------
# Traces not found
# ---------------------
# Call the Shot not found
# ---------------------
# Fist With Great Ambition not found
# ---------------------
# Blue Tarps not found
# ---------------------
# RÃ©solution not found
# ---------------------
# Rome not found
# ---------------------
# Het Groene Woud, Brabant tussen steden not found
# ---------------------
# Water and Salt not found
# ---------------------
# A Screen Test for an Adaptation of Giselle not found
# ---------------------
# Nothing to be Afraid of not found
# ---------------------
# The Commission not found
# ---------------------
# Unstable not found
# ---------------------
# Maids for Sale not found
# ---------------------
# A Million Eyes not found
# ---------------------
# In Her Hands not found
# ---------------------
# A Candle in the Window not found
# ---------------------
# Demons not found
# ---------------------
# My Friend, My Enemy not found
# ---------------------
# Keep Safe Distance not found
# ---------------------
# Sisters: Dream & Variations not found
# ---------------------
# Beauty Standards not found
# ---------------------
# The Bartered Bride not found
# ---------------------
# Is That All There Is? not found
# ---------------------
# Desert Wolf not found
# ---------------------
# Nick Lowe with Los Straitjackets: Live from First Avenue not found
# ---------------------
# The Importance of Being Earnest - BARRY not found
# ---------------------
# Memoirs of a Spectrum Addict 2.5: The Lost Tapes not found
# ---------------------
# Mark Ellis: Dog Stepfather not found
# ---------------------
# Silverback not found
# ---------------------
# corruption not found
# ---------------------
# Blockbuster Where a Giant Monster Destroys a Town not found
# ---------------------
# Mike Falzone: You Got Toes? not found
# ---------------------
# England 79 not found
# ---------------------
# Requiem not found
# ---------------------
# Inside the Bum not found
# ---------------------
# short/cut not found
# ---------------------
# Off Fleek not found
# ---------------------
# Entropia not found
# ---------------------
# A Love is an Comedy, Drama, Fantasy movie with a IMDB sorec of 7.2, a Meta score of 62, and made 446165 at the box office
# ---------------------
# Love the Sinner not found
# ---------------------
# Keep Breathing not found
# ---------------------
# Eastern State not found
# ---------------------
# PHX [X is for Xylonite] not found
# ---------------------
# Maggie May not found
# ---------------------
# Raving Riot not found
# ---------------------
# The Fish Out of Water not found
# ---------------------
# HERO is an Action, Adventure, Drama movie with a IMDB sorec of 7.9, a Meta score of 85, and made 53710019 at the box office
# ---------------------
# Undertows not found
# ---------------------
# Bakemono not found
# ---------------------
# If You Knew not found
# ---------------------
# Hearth not found
# ---------------------
# Shed not found
# ---------------------
# Adam is an Comedy, Drama, Romance movie with a IMDB sorec of 7.1, a Meta score of 56, and made 2277396 at the box office
# ---------------------
# Laynie Needs a Light not found
# ---------------------
# Lithic Choreographies not found
# ---------------------
# Confound not found
# ---------------------
# About Time, Too: Ivy's Story not found
# ---------------------
# PFL Playoffs 2019 - PFL 7: Michaud vs. Franca not found
# ---------------------
# PFL Finals 2019 - PFL 10: Harrison vs Pacheco not found
# ---------------------
# Two Stones not found
# ---------------------
# The Knight of Hope not found
# ---------------------
# Crossed not found
# ---------------------
# The Hunt is an Drama movie with a IMDB sorec of 8.3, a Meta score of 77, and made 613308 at the box office
# ---------------------
# Lost Odyssey: The Book of Knowledge not found
# ---------------------
# Lantun Rakyat not found
# ---------------------
# Romeo + Juliet Act I Scene V not found
# ---------------------
# 2x+xy=1 not found
# ---------------------
# Sidney Crosby: There's No Place Like Home not found
# ---------------------
# Roommate Raid not found
# ---------------------
# Innocent Love not found
# ---------------------
# The Blood Flowed not found
# ---------------------
# Paper Clocks not found
# ---------------------
# Spinning Dry not found
# ---------------------
# Thankful for My Family not found
# ---------------------
# Esther Manito: Crusade not found
# ---------------------
# Abscond not found
# ---------------------
# Gasoline is an Crime, Drama, Romance movie with a IMDB sorec of 5.2, a Meta score of 44, and made 11023 at the box office
# ---------------------
# Rescatado not found
# ---------------------
# Land of Little Rivers not found
# ---------------------
# Tomatoes not found
# ---------------------
# Dirt Ash Meat not found
# ---------------------
# The Painting is an Animation, Adventure, Drama movie with a IMDB sorec of 7.3, a Meta score of 70, and made 21008 at the box office
# ---------------------
# Lake is an Drama, Fantasy, Romance movie with a IMDB sorec of 6.8, a Meta score of 52, and made 52330111 at the box office
# ---------------------
# ON THE OTHER SIDE not found
# ---------------------
# MISSING is an Biography, Drama, History movie with a IMDB sorec of 7.7, a Meta score of 78, and made 14000000 at the box office
# ---------------------
# Happy Hour at High Noon not found
# ---------------------
# Christmas World: The Bird's Christmas Carol not found
# ---------------------
# It's Christmas Sing Along not found
# ---------------------
# Highlights Watch & Learn!: Honesty and Tough Choices not found
# ---------------------
# Highlights Watch & Learn!: Too Cool! not found
# ---------------------
# Highlights Watch & Learn!: Manners, Please! not found
# ---------------------
# Highlights Watch & Learn!: Snow Day! not found
# ---------------------
# Highlights Watch & Learn!: Family Fun! not found
# ---------------------
# Remarkable not found
# ---------------------
# In League With Gaddafi not found
# ---------------------
# Intersounds not found
# ---------------------
# Diamond is Unbreakable Retold not found
# ---------------------
# Killing Time with Lizzie Boredom not found
# ---------------------
# Of Kings and Paintings not found
# ---------------------
# T.S. Eliot: The Search for Happiness not found
# ---------------------
# The Making of Kitbull not found
# ---------------------
# Hummingbird not found
# ---------------------
# George Michael: Got to Have Faith not found
# ---------------------
# The Calling of the Things Beyond not found
# ---------------------
# Ever Fallen not found
# ---------------------
# Death Stranding: Inside Kojima Productions not found
# ---------------------
# Rear View not found
# ---------------------
# Hard Christmas not found
# ---------------------
# Legend of the Wendigo not found
# ---------------------
# Rodelinda not found
# ---------------------
# Commonality not found
# ---------------------
# The Christmas Visitor not found
# ---------------------
# I Am Joseph not found
# ---------------------
